]
svm_pe=[
1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767, 1064.3437086573767
]

# RSF
rsf_c_index=[
0.404493133089616, 0.442730461416856, 0.416250864539077, 0.420030135362118, 0.417856437110957, 0.397008694793005, 0.423685900602707, 0.416843691334848, 0.420771168856832, 0.427687481474163, 0.414175970753878, 0.413583143958107, 0.445743997628693, 0.435221322003755, 0.432603003655765, 0.413632546191088, 0.394983203240787, 0.40629631459342, 0.414867602015611, 0.426156012251754
]
rsf_ibs=[
0.202061957721494, 0.204874373090891, 0.199992787154953, 0.200879402684247, 0.199073981994447, 0.201044331786232, 0.20404540598623, 0.199556287917479, 0.200925454046313, 0.198540630953123, 0.202801458236779, 0.201049465128652, 0.203058811285153, 0.200839199398703, 0.201395745536644, 0.199774863236316, 0.202944405902017, 0.203584846245897, 0.19903631840986, 0.20058731636463
]
rsf_pe=[
718.743159830922, 717.46720909731, 718.758360712632, 719.866599373951, 718.105476684215, 718.331108057727, 717.373435499126, 716.10838467333, 718.659003146939, 717.278100291421, 717.912230451949, 720.219335057273, 717.452170775855, 717.031441236608, 717.554683119404, 716.905358446872, 719.819167045413, 718.545780265376, 717.697626247377, 718.218245030517
]

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'CPH': [cph_c_index, cph_ibs, cph_pe],
    'Deepsurv': [deepsurv_c_index, deepsurv_ibs, deepsurv_pe],
    'Survival SVM': [svm_c_index, [], svm_pe],
    'RSF': [rsf_c_index, rsf_ibs, rsf_pe]
}

# Evaluation metrics
metrics = ['C-Index', 'Integrated Brier Scores', 'Prediction Error for 5-year RMST']

# %%
# Plot boxplots
fig, axes = plt.subplots(nrows=len(metrics), ncols=1, figsize=(8, 8))

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.set_title("Boxplot of " + metric + " over 20 Replicates", fontweight='bold')

    # Extract data for the metric
    metric_data = []
    labels = []
    for method, values in data.items():
        if len(values) > i:
            metric_data.append(values[i])
            labels.append(method)

    # Create boxplot
    ax.boxplot(metric_data, labels=labels)

plt.tight_layout()
plt.show()
