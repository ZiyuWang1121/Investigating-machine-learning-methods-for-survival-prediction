# %%
# CPH
cph_c_index=[ 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039, 0.301681850035039 ]
cph_ibs=[ 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241, 0.357158797578241 ]

# Deepsurv
deepsurv_c_index=[0.7977034785545424, 0.7747382640999663, 0.7882472137791287, 0.7792975346166836, 0.7561634582911179, 0.7521107733873691, 0.8007429922323539, 0.7804795677136103, 0.7890915231340764, 0.7689969604863222, 0.7713610266801756, 0.784532252617359, 0.7419790611279973, 0.7911178655859507, 0.7646065518405943, 0.7825059101654847, 0.7885849375211077, 0.7413036136440392, 0.7973657548125633, 0.7894292468760554]
deepsurv_ibs=[0.17009573069917183, 0.19217807539554735, 0.1979318839866176, 0.15267630404236873, 0.1407509140297592, 0.13667836901072075, 0.19548737592763352, 0.17222507829899159, 0.20380911567651663, 0.17291855991293054, 0.1929288657291904, 0.1766539153158396, 0.17228113436427944, 0.12733731099909418, 0.14548151705163287, 0.1767928947337889, 0.1472173009517811, 0.14777515688965545, 0.17349071348539027, 0.19478800885924966]

# Survival SVM
svm_c_index=[0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118, 0.6114905584572118]
svm_ibs=[]

# RSF
rsf_c_index=[0.462960675822547, 0.439049995059777, 0.444138425056813, 0.450634818693805, 0.442014129038633, 0.441791818990218, 0.458366268155321, 0.441149589961466, 0.461676217765043, 0.447967098112835, 0.453253137041794, 0.44875753384053, 0.456612488884498, 0.436283470012845, 0.45463639956526, 0.457946349174983, 0.454809307380694, 0.442779863649837, 0.45461169844877, 0.458588578203735]
rsf_ibs=[0.211587207068184, 0.20812489241319, 0.212599157302288, 0.212081971361363, 0.21542116847829, 0.214919562237381, 0.21475167368111, 0.213017661996529, 0.213925167560976, 0.214553710802021, 0.213237076615093, 0.214770083245593, 0.210927024393557, 0.214502391827146, 0.210567396300822, 0.213087268544668, 0.214746915375295, 0.2123498420931, 0.21415369615154, 0.21088072008992]

# %%
import numpy as np

# Assuming cph_c_index, cph_ibs, deepsurv_c_index, deepsurv_ibs, svm_c_index, rsf_c_index, rsf_ibs are defined

# Confidence Level and Z-score
confidence_level = 0.95
z_score = 1.96  # for 95% confidence level

# Function to calculate confidence interval
def calculate_confidence_interval(data, z_score):
    mean = np.mean(data)
    std = np.std(data)
    margin_error = z_score * (std / np.sqrt(len(data)))
    ci_lower = mean - margin_error
    ci_upper = mean + margin_error
    return mean, ci_lower, ci_upper

# Confidence Intervals
cph_c_ci = calculate_confidence_interval(cph_c_index, z_score)
cph_ibs_ci = calculate_confidence_interval(cph_ibs, z_score)
deepsurv_c_ci = calculate_confidence_interval(deepsurv_c_index, z_score)
deepsurv_ibs_ci = calculate_confidence_interval(deepsurv_ibs, z_score)
svm_c_ci = calculate_confidence_interval(svm_c_index, z_score)
rsf_c_ci = calculate_confidence_interval(rsf_c_index, z_score)
rsf_ibs_ci = calculate_confidence_interval(rsf_ibs, z_score)

# Print results
print("CPH C-Index Confidence Interval: (C-index: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(cph_c_ci[0], cph_c_ci[1],cph_c_ci[2]))
print("CPH IBS Confidence Interval: (IBS: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(cph_ibs_ci[0], cph_ibs_ci[1], cph_ibs_ci[2]))
print("DeepSurv C-Index Confidence Interval: (C-index: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(deepsurv_c_ci[0], deepsurv_c_ci[1], deepsurv_c_ci[2]))
print("DeepSurv IBS Confidence Interval: (IBS: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(deepsurv_ibs_ci[0], deepsurv_ibs_ci[1], deepsurv_ibs_ci[2]))
print("Survival SVM C-Index Confidence Interval: (C-index: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(svm_c_ci[0], svm_c_ci[1], svm_c_ci[2]))
print("Random Survival Forest C-Index Confidence Interval: (C-index: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(rsf_c_ci[0], rsf_c_ci[1], rsf_c_ci[2]))
print("Random Survival Forest IBS Confidence Interval: (IBS: {:.3f}; 95% CI: ({:.3f},{:.3f}))".format(rsf_ibs_ci[0], rsf_ibs_ci[1], rsf_ibs_ci[2]))
# Out:
# CPH C-Index Confidence Interval: (C-index: 0.302; 95% CI: (0.302,0.302))
# CPH IBS Confidence Interval: (IBS: 0.357; 95% CI: (0.357,0.357))
# DeepSurv C-Index Confidence Interval: (C-index: 0.777; 95% CI: (0.769,0.785))
# DeepSurv IBS Confidence Interval: (IBS: 0.169; 95% CI: (0.160,0.179))
# Survival SVM C-Index Confidence Interval: (C-index: 0.611; 95% CI: (0.611,0.611))
# Random Survival Forest C-Index Confidence Interval: (C-index: 0.450; 95% CI: (0.447,0.454))
# Random Survival Forest IBS Confidence Interval: (IBS: 0.213; 95% CI: (0.212,0.214))

# %%
#import matplotlib.pyplot as plt

# Data
data = {
    'CPH': [cph_c_index, cph_ibs],
    'Deepsurv': [deepsurv_c_index, deepsurv_ibs],
    'Survival SVM': [svm_c_index, []],
    'RSF': [rsf_c_index, rsf_ibs]
}

# Evaluation metrics
metrics = ['C-Index', 'Integrated Brier Scores']

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

plt.figure(figsize=(8, 5))  # Increased figure size

# Create boxplot
a = "white"
b = "deeppink"
plt.boxplot(data.values(), patch_artist=True,
            boxprops=dict(facecolor=a, color=b),
            capprops=dict(color=b),
            whiskerprops=dict(color=b),
            flierprops=dict(color=a, markeredgecolor=a),
            medianprops=dict(color=b),
            )

data = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

c = "white"      # Color for the lines
d = "black"
plt.boxplot(data.values(), patch_artist=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=c, markeredgecolor=c),
            medianprops=dict(color=d),
            )

plt.xticks(range(1, len(data) + 1), data.keys(), fontsize=12)  # Increased x-axis font size
plt.yticks(fontsize=12)  # Increased y-axis font size
plt.ylabel('Values', fontsize=12)  # Increased ylabel font size
plt.title('Boxplot of C-Index & IBS for Different Models over 20 Replicates', fontsize=14)  # Increased title font size

# Manually create legend with specified colors
legend_labels = ['C-Index', 'IBS']
legend_handles = [
    plt.Line2D([0], [0], color=b, linewidth=4),
    plt.Line2D([0], [0], color=d, linewidth=4)
]

plt.legend(legend_handles, legend_labels, loc='best', fontsize=12)  # Increased legend font size

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the highest mean value for C-Index and the lowest mean value for IBS
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Colors for highlighting
highlight_color_c_index = "red"  # Highlight color for C-Index
highlight_color_ibs = "blue"     # Highlight color for IBS

# Plotting
plt.figure(figsize=(8, 5))

# Plot C-Index boxplot
plt.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor="white", color=highlight_color_c_index),
            capprops=dict(color=highlight_color_c_index),
            whiskerprops=dict(color=highlight_color_c_index),
            flierprops=dict(color="white", markeredgecolor="white"),
            medianprops=dict(color=highlight_color_c_index),
            meanprops=dict(marker='o', markerfacecolor=highlight_color_c_index, markeredgecolor='black', markersize=10)
            )

# Plot IBS boxplot
plt.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor="white", color=highlight_color_ibs),
            capprops=dict(color=highlight_color_ibs),
            whiskerprops=dict(color=highlight_color_ibs),
            flierprops=dict(color="white", markeredgecolor="white"),
            medianprops=dict(color=highlight_color_ibs),
            meanprops=dict(marker='o', markerfacecolor=highlight_color_ibs, markeredgecolor='black', markersize=10)
            )

c = "white"      # Color for the lines
d = "black"
plt.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=c, markeredgecolor=c),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=highlight_color_ibs, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
plt.xticks(range(1, len(data_c_index) + 1), data_c_index.keys(), fontsize=12)

# Customize y-axis ticks and labels
plt.yticks(fontsize=12)
plt.ylabel('Values', fontsize=12)

# Set plot title
plt.title('Boxplot of C-Index & IBS for Different Models over 20 Replicates', fontsize=14)

# Manually create legend with specified colors
legend_labels = ['C-Index', 'IBS', f'Highest C-Index: {max_mean_c_index}', f'Lowest IBS: {min_mean_ibs}']
legend_handles = [
    plt.Line2D([0], [0], color=highlight_color_c_index, linewidth=4),
    plt.Line2D([0], [0], color=highlight_color_ibs, linewidth=4),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=highlight_color_c_index, markeredgecolor='black', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=highlight_color_ibs, markeredgecolor='black', markersize=10)
]

# Add legend to the plot
plt.legend(legend_handles, legend_labels, loc='best', fontsize=12)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the highest mean value for C-Index and the lowest mean value for IBS
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Create figure and subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))



c = "white"      # Color for the lines
d = "black"

# Plot C-Index boxplot
bp_c_index = ax1.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax1.set_xticks(range(1, len(data_c_index) + 1))
ax1.set_xticklabels(data_c_index.keys())
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.set_ylabel('C-Index', fontsize=12)

# Hide x-label
ax1.set_xlabel('')

# Hide x-label
ax1.xaxis.set_visible(False)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')


c = "white"      # Color for the lines
d = "black"

# Plot IBS boxplot
bp_ibs = ax2.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax2.set_xticks(range(1, len(data_ibs) + 1))
ax2.set_xticklabels(data_ibs.keys())
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)
ax2.set_ylabel('IBS', fontsize=12)

# Highlight the best scoring model for IBS with a blue marker
bp_ibs['means'][list(data_ibs.keys()).index(min_mean_ibs)].set_markerfacecolor('blue')

# Add x-axis label to the last subplot
# ax2.set_xlabel('Models', fontsize=14)

# Add legend to the plot
legend_labels = [f'Model with the highest C-Index: {max_mean_c_index}', f'Model with the lowest IBS: {min_mean_ibs}']
legend_handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markeredgecolor='black', markersize=10)
]

fig.legend(legend_handles, legend_labels, loc='right', fontsize=12)

# Set common title for both subplots
fig.suptitle('Boxplot of C-Index & IBS for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the highest mean value for C-Index and the lowest mean value for IBS
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Create figure and subplots
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10))

c = "white"      # Color for the lines
d = "black"

# Plot C-Index boxplot
bp_c_index = ax1.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax1.set_xticks(range(1, len(data_c_index) + 1))
ax1.set_xticklabels(data_c_index.keys())
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.set_ylabel('C-Index', fontsize=12)

# Hide x-axis label and ticks
ax1.set_xlabel('')
ax1.xaxis.set_visible(False)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')


c = "white"      # Color for the lines
d = "black"

# Plot IBS boxplot
bp_ibs = ax2.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax2.set_xticks(range(1, len(data_ibs) + 1))
ax2.set_xticklabels(data_ibs.keys())
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)
ax2.set_ylabel('IBS', fontsize=12)

# Highlight the best scoring model for IBS with a blue marker
bp_ibs['means'][list(data_ibs.keys()).index(min_mean_ibs)].set_markerfacecolor('blue')

# Add x-axis label to the last subplot
# ax2.set_xlabel('Models', fontsize=14)

# Set common title for both subplots
fig.suptitle('Boxplot of C-Index & IBS for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Add legend outside the plot
legend_labels = [f'Highest C-Index:\n{max_mean_c_index}', f'Lowest IBS:\n{min_mean_ibs}']
legend_handles = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markeredgecolor='black', markersize=10)
]

fig.legend(legend_handles, legend_labels, loc='right', fontsize=12, bbox_to_anchor=(1.25, 0.5))

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}

# Determine the dataset with the highest mean value for C-Index
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)

# Create figure and subplot
fig1, ax1 = plt.subplots(figsize=(8, 6))

c = "white"      # Color for the lines
d = "black"

# Plot C-Index boxplot
bp_c_index = ax1.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax1.set_xticks(range(1, len(data_c_index) + 1))
ax1.set_xticklabels(data_c_index.keys())
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.set_ylabel('C-Index', fontsize=12)

# Hide x-axis label and ticks
ax1.set_xlabel('')
ax1.xaxis.set_visible(False)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')

# Set title for the subplot
fig1.suptitle('Boxplot of C-Index for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Add legend outside the plot
legend_labels_c_index = [f'Highest C-Index: {max_mean_c_index}']
legend_handles_c_index = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10)
]

fig1.legend(legend_handles_c_index, legend_labels_c_index, loc='upper right', fontsize=12)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}

# Determine the dataset with the highest mean value for C-Index
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)

# Create figure and subplot
fig1, ax1 = plt.subplots(figsize=(8, 5))

c = "white"      # Color for the lines
d = "black"

# Plot C-Index boxplot
bp_c_index = ax1.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax1.set_xticks(range(1, len(data_c_index) + 1))
ax1.set_xticklabels(data_c_index.keys())
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.set_ylabel('C-Index', fontsize=12)

# Hide x-axis label and ticks
ax1.set_xlabel('')
ax1.xaxis.set_visible(False)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')

# Set title for the subplot
fig1.suptitle('Boxplot of C-Index for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Add legend outside the plot
legend_labels_c_index = [f'Model (highest C-Index): {max_mean_c_index}']
legend_handles_c_index = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10)
]

fig1.legend(legend_handles_c_index, legend_labels_c_index, loc='upper right', fontsize=12, bbox_to_anchor=(0.98, 0.90))

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the lowest mean value for IBS
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Create figure and subplot
fig2, ax2 = plt.subplots(figsize=(8, 5))

c = "white"      # Color for the lines
d = "black"

# Plot IBS boxplot
bp_ibs = ax2.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax2.set_xticks(range(1, len(data_ibs) + 1))
ax2.set_xticklabels(data_ibs.keys())
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)
ax2.set_ylabel('IBS', fontsize=12)

# Highlight the best scoring model for IBS with a blue marker
bp_ibs['means'][list(data_ibs.keys()).index(min_mean_ibs)].set_markerfacecolor('blue')

# Set title for the subplot
fig2.suptitle('Boxplot of IBS for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Add legend outside the plot
legend_labels_ibs = [f'Model (lowest IBS): {min_mean_ibs}']
legend_handles_ibs = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markeredgecolor='black', markersize=10)
]

fig2.legend(legend_handles_ibs, legend_labels_ibs, loc='right', fontsize=12, bbox_to_anchor=(0.98, 0.85))

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the highest mean value for C-Index and the lowest mean value for IBS
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Create figure and subplots
fig1, ax1 = plt.subplots(figsize=(8, 6))
fig2, ax2 = plt.subplots(figsize=(8, 6))

c = "white"      # Color for the lines
d = "black"

# Plot C-Index boxplot
bp_c_index = ax1.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax1.set_xticks(range(1, len(data_c_index) + 1))
ax1.set_xticklabels(data_c_index.keys())
ax1.tick_params(axis='x', labelsize=12)
ax1.tick_params(axis='y', labelsize=12)
ax1.set_ylabel('C-Index', fontsize=12)

# Hide x-axis label and ticks
ax1.set_xlabel('')
ax1.xaxis.set_visible(False)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')


c = "white"      # Color for the lines
d = "black"

# Plot IBS boxplot
bp_ibs = ax2.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor=c, color=d),
            capprops=dict(color=d),
            whiskerprops=dict(color=d),
            flierprops=dict(color=d, markeredgecolor=d),
            medianprops=dict(color=d),
            meanprops=dict(marker='o', markerfacecolor=d, markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
ax2.set_xticks(range(1, len(data_ibs) + 1))
ax2.set_xticklabels(data_ibs.keys())
ax2.tick_params(axis='x', labelsize=12)
ax2.tick_params(axis='y', labelsize=12)
ax2.set_ylabel('IBS', fontsize=12)

# Highlight the best scoring model for IBS with a blue marker
bp_ibs['means'][list(data_ibs.keys()).index(min_mean_ibs)].set_markerfacecolor('blue')

# Add x-axis label to the last subplot
# ax2.set_xlabel('Models', fontsize=14)

# Set common title for both subplots
fig1.suptitle('Boxplot of C-Index for Different Models over 20 Replicates', fontsize=14)
fig2.suptitle('Boxplot of IBS for Different Models over 20 Replicates', fontsize=14)

# Adjust layout to prevent overlapping
plt.tight_layout()

# Add legend outside the plot
legend_labels_c_index = [f'Highest C-Index:\n{max_mean_c_index}']
legend_handles_c_index = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10)
]

legend_labels_ibs = [f'Lowest IBS:\n{min_mean_ibs}']
legend_handles_ibs = [
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markeredgecolor='black', markersize=10)
]

fig1.legend(legend_handles_c_index, legend_labels_c_index, loc='upper right', fontsize=12)
fig2.legend(legend_handles_ibs, legend_labels_ibs, loc='upper right', fontsize=12)

# Display the plots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
data_c_index = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

data_ibs = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

# Calculate mean values for each dataset, filtering out empty values
mean_values_c_index = {model: np.mean(values) for model, values in data_c_index.items() if values}
mean_values_ibs = {model: np.mean(values) for model, values in data_ibs.items() if values}

# Determine the dataset with the highest mean value for C-Index and the lowest mean value for IBS
max_mean_c_index = max(mean_values_c_index, key=mean_values_c_index.get)
min_mean_ibs = min(mean_values_ibs, key=mean_values_ibs.get)

# Plotting
plt.figure(figsize=(8, 5))

# Plot C-Index boxplot
bp_c_index = plt.boxplot(data_c_index.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor="white", color="black"),
            capprops=dict(color="black"),
            whiskerprops=dict(color="black"),
            flierprops=dict(color="black", markeredgecolor="black"),
            medianprops=dict(color="black"),
            meanprops=dict(marker='o', markerfacecolor="black", markeredgecolor='black', markersize=10)
            )

# Plot IBS boxplot
bp_ibs = plt.boxplot(data_ibs.values(), patch_artist=True, showmeans=True,
            boxprops=dict(facecolor="white", color="black"),
            capprops=dict(color="black"),
            whiskerprops=dict(color="black"),
            flierprops=dict(color="black", markeredgecolor="black"),
            medianprops=dict(color="black"),
            meanprops=dict(marker='o', markerfacecolor="black", markeredgecolor='black', markersize=10)
            )

# Customize x-axis ticks
plt.xticks(range(1, len(data_c_index) + 1), data_c_index.keys(), fontsize=12)

# Customize y-axis ticks and labels
plt.yticks(fontsize=12)
plt.ylabel('Values', fontsize=12)

# Set plot title
plt.title('Boxplot of C-Index & IBS for Different Models over 20 Replicates', fontsize=14)

# Highlight the best scoring model for C-Index with a red marker
bp_c_index['means'][list(data_c_index.keys()).index(max_mean_c_index)].set_markerfacecolor('red')

# Highlight the best scoring model for IBS with a blue marker
bp_ibs['means'][list(data_ibs.keys()).index(min_mean_ibs)].set_markerfacecolor('blue')

# Manually create legend with specified colors
legend_labels = ['C-Index', 'IBS', f'Highest C-Index: {max_mean_c_index}', f'Lowest IBS: {min_mean_ibs}']
legend_handles = [
    plt.Line2D([0], [0], color="black", linewidth=4),
    plt.Line2D([0], [0], color="black", linewidth=4),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='red', markeredgecolor='black', markersize=10),
    plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markeredgecolor='black', markersize=10)
]

# Add legend to the plot
plt.legend(legend_handles, legend_labels, loc='best', fontsize=12)

# Display the plot
plt.show()

# %%
from matplotlib.ticker import StrMethodFormatter

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'CPH': cph_c_index,
    'Deepsurv': deepsurv_c_index,
    'Survival SVM': svm_c_index,
    'RSF': rsf_c_index
}

plt.figure(figsize=(8, 5))  # Increased figure size

# Create boxplot
plt.boxplot(data.values())

plt.xticks(range(1, len(data) + 1), data.keys(), fontsize=12)  # Increased x-axis font size
plt.yticks(fontsize=12)  # Increased y-axis font size
plt.ylabel('Values', fontsize=12)  # Increased ylabel font size
plt.title('Boxplot of C-Index over 20 Replicates', fontsize=16)  # Increased title font size

# Set decimal places for y-axis labels
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:.2f}'))

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'CPH': cph_ibs,
    'Deepsurv': deepsurv_ibs,
    'Survival SVM': [],
    'RSF': rsf_ibs
}

plt.figure(figsize=(8, 5))  # Increased figure size

# Create boxplot
plt.boxplot(data.values())

plt.xticks(range(1, len(data) + 1), data.keys(), fontsize=12)  # Increased x-axis font size
plt.yticks(fontsize=12)  # Increased y-axis font size
plt.title('Boxplot of IBS over 20 Replicates', fontsize=16)  # Increased title font size

# Set decimal places for y-axis labels
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:.2f}'))

plt.show()

# %%
# Plot boxplots
fig, axes = plt.subplots(nrows=len(metrics), ncols=1, figsize=(5, 8)) # or 5.5,9

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.set_title("" + metric + " over 20 Replicates", fontsize=14)

    # Extract data for the metric
    metric_data = []
    labels = []
    for method, values in data.items():
        if len(values) > i:
            metric_data.append(values[i])
            labels.append(method)

    # Create boxplot
    ax.boxplot(metric_data, labels=labels)
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot boxplots
fig, axes = plt.subplots(nrows=1, ncols=len(metrics), figsize=(16, 3))

for i, metric in enumerate(metrics):
    ax = axes[i]
    ax.set_title("" + metric + " over 20 Replicates", fontsize=14)

    # Extract data for the metric
    metric_data = []
    labels = []
    for method, values in data.items():
        if len(values) > i:
            metric_data.append(values[i])
            labels.append(method)

    # Create boxplot
    ax.boxplot(metric_data, labels=labels)
     # Set font size for tick labels
    ax.tick_params(axis='both', which='major', labelsize=12)

plt.tight_layout()
plt.show()
